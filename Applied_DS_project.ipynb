# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("marketing_data.csv") 
df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df['Year_Birth']
# Out:
# 0       1970
# 1       1961
# 2       1958
# 3       1967
# 4       1989
#         ...
# 2235    1976
# 2236    1977
# 2237    1976
# 2238    1978
# 2239    1969
# Name: Year_Birth, Length: 2240, dtype: int64

# %%
df.columns = [col.replace(' ', '') for col in df.columns]

# %%
df.columns=df.columns.str.upper()
df['EDUCATION'] = df['EDUCATION'].str.lower()
df['MARITAL_STATUS'] = df['MARITAL_STATUS'].str.lower()
df['COUNTRY'] = df['COUNTRY'].str.lower()
df
# Out:
#          ID  YEAR_BIRTH   EDUCATION MARITAL_STATUS       INCOME  KIDHOME  \
# 0      1826        1970  graduation       divorced  $84,835.00         0
# 1         1        1961  graduation         single  $57,091.00         0
# 2     10476        1958  graduation        married  $67,267.00         0
# 3      1386        1967  graduation       together  $32,474.00         1
# 4      5371        1989  graduation         single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         phd       divorced  $66,476.00         0
# 2236   5263        1977    2n cycle        married  $31,056.00         1
# 2237     22        1976  graduation       divorced  $46,310.00         1
# 2238    528        1978  graduation        married  $65,819.00         0
# 2239   4070        1969         phd        married  $94,871.00         0
#
#       TEENHOME DT_CUSTOMER  RECENCY  MNTWINES  ...  NUMSTOREPURCHASES  \
# ...

# %%
data_types = df.dtypes
print(data_types)
# Out:
# ID                      int64
# YEAR_BIRTH              int64
# EDUCATION              object
# MARITAL_STATUS         object
# INCOME                 object
# KIDHOME                 int64
# TEENHOME                int64
# DT_CUSTOMER            object
# RECENCY                 int64
# MNTWINES                int64
# MNTFRUITS               int64
# MNTMEATPRODUCTS         int64
# MNTFISHPRODUCTS         int64
# MNTSWEETPRODUCTS        int64
# MNTGOLDPRODS            int64
# NUMDEALSPURCHASES       int64
# NUMWEBPURCHASES         int64
# NUMCATALOGPURCHASES     int64
# NUMSTOREPURCHASES       int64
# NUMWEBVISITSMONTH       int64
# ACCEPTEDCMP3            int64
# ACCEPTEDCMP4            int64
# ACCEPTEDCMP5            int64
# ACCEPTEDCMP1            int64
# ACCEPTEDCMP2            int64
# RESPONSE                int64
# COMPLAIN                int64
# COUNTRY                object
# dtype: object

# %%
df['INCOME']= df['INCOME'].astype('string')

# %%
df['INCOME'] = df['INCOME'].str.replace('$', '')
df['INCOME'] = df['INCOME'].str.replace(',', '')
# Out:
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\56818503.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['INCOME'] = df['INCOME'].str.replace('$', '')

# %%
df['DT_CUSTOMER']= pd.to_datetime(df['DT_CUSTOMER'])
#df['YEAR_BIRTH']=pd.to_datetime(df['YEAR_BIRTH'])
df['EDUCATION']= df['EDUCATION'].astype('string')
df['MARITAL_STATUS']= df['MARITAL_STATUS'].astype('string')
df['COUNTRY'] = df['COUNTRY'].astype('string')
df['INCOME']= pd.to_numeric(df['INCOME'])
df['ID'] = df['ID'].astype('int64')

# %%
df['YEAR_BIRTH']
# Out:
# 0       1970
# 1       1961
# 2       1958
# 3       1967
# 4       1989
#         ...
# 2235    1976
# 2236    1977
# 2237    1976
# 2238    1978
# 2239    1969
# Name: YEAR_BIRTH, Length: 2240, dtype: int64

# %%
duplicates_exist = df.duplicated().any()

#make sure we dont have repeated values 
if duplicates_exist:
    print("Duplicates exist in the CSV file.")
else:
    print("No duplicates found in the CSV file.")
# Out:
# No duplicates found in the CSV file.

# %%
missing_values_count = df.isnull().sum()
print(missing_values_count)
# Out:
# ID                      0
# YEAR_BIRTH              0
# EDUCATION               0
# MARITAL_STATUS          0
# INCOME                 24
# KIDHOME                 0
# TEENHOME                0
# DT_CUSTOMER             0
# RECENCY                 0
# MNTWINES                0
# MNTFRUITS               0
# MNTMEATPRODUCTS         0
# MNTFISHPRODUCTS         0
# MNTSWEETPRODUCTS        0
# MNTGOLDPRODS            0
# NUMDEALSPURCHASES       0
# NUMWEBPURCHASES         0
# NUMCATALOGPURCHASES     0
# NUMSTOREPURCHASES       0
# NUMWEBVISITSMONTH       0
# ACCEPTEDCMP3            0
# ACCEPTEDCMP4            0
# ACCEPTEDCMP5            0
# ACCEPTEDCMP1            0
# ACCEPTEDCMP2            0
# RESPONSE                0
# COMPLAIN                0
# COUNTRY                 0
# dtype: int64

# %%
df = df.dropna()

# %%
import pandas as pd
from datetime import datetime

# Convert column names to uppercase

# Calculate the number of children
df["NUMBER_CHILDREN"] = df["KIDHOME"] + df["TEENHOME"]

# Get the current year
current_year = datetime.now().year



# Calculate age using a DateOffset
df['AGE'] = current_year - df['YEAR_BIRTH']

# Calculate total spending
df["TOTAL_SPENDING"] = df["MNTMEATPRODUCTS"] + df["MNTFISHPRODUCTS"] + df["MNTSWEETPRODUCTS"] + df["MNTGOLDPRODS"] + df["MNTWINES"] + df["MNTFRUITS"]

# Convert column names to uppercase again
#df.columns = df.columns.str.upper()
print(df['AGE'])
print("==========================")
print(df['TOTAL_SPENDING'])
# Out:
# 0       53
# 1       62
# 2       65
# 3       56
# 4       34
#         ..
# 2235    47
# 2236    46
# 2237    47
# 2238    45
# 2239    54
# Name: AGE, Length: 2216, dtype: int64
# ...
# 0       1190
# 1        577
# 2        251
# 3         11
# 4         91
#         ...
# 2235     689
# 2236      55
# 2237     309
# 2238    1383
# 2239    1078
# Name: TOTAL_SPENDING, Length: 2216, dtype: int64
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\2484583330.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NUMBER_CHILDREN"] = df["KIDHOME"] + df["TEENHOME"]
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\2484583330.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.dtypes
# Out:
# ID                              int64
# YEAR_BIRTH                      int64
# EDUCATION                      string
# MARITAL_STATUS                 string
# INCOME                        float64
# KIDHOME                         int64
# TEENHOME                        int64
# DT_CUSTOMER            datetime64[ns]
# RECENCY                         int64
# MNTWINES                        int64
# MNTFRUITS                       int64
# MNTMEATPRODUCTS                 int64
# MNTFISHPRODUCTS                 int64
# MNTSWEETPRODUCTS                int64
# MNTGOLDPRODS                    int64
# NUMDEALSPURCHASES               int64
# NUMWEBPURCHASES                 int64
# NUMCATALOGPURCHASES             int64
# NUMSTOREPURCHASES               int64
# NUMWEBVISITSMONTH               int64
# ACCEPTEDCMP3                    int64
# ACCEPTEDCMP4                    int64
# ACCEPTEDCMP5                    int64
# ACCEPTEDCMP1                    int64
# ACCEPTEDCMP2                    int64
# ...

# %%
import pandas as pd
import datetime

# Assuming you've already loaded your data into the 'df' DataFrame

# Convert column names to uppercase
df.columns = df.columns.str.upper()

# Calculate the number of children
df["NUMBER_CHILDREN"] = df["KIDHOME"] + df["TEENHOME"]

# Get the current year
current_year = datetime.datetime.now().year

# Calculate age by subtracting the 'YEAR_BIRTH' column (which contains only years) from the current year
df["AGE"] = current_year - df["YEAR_BIRTH"]

# Calculate total spending and create a new column 'TOTAL_SPENDING'
df["TOTAL_SPENDING"] = df["MNTMEATPRODUCTS"] + df["MNTFISHPRODUCTS"] + df["MNTSWEETPRODUCTS"] + df["MNTGOLDPRODS"] + df["MNTWINES"] + df["MNTFRUITS"]

# Now, you can print the 'AGE' column
print(df["AGE"])
print("==========================")
print(df["TOTAL_SPENDING"])
# Out:
# 0       53
# 1       62
# 2       65
# 3       56
# 4       34
#         ..
# 2235    47
# 2236    46
# 2237    47
# 2238    45
# 2239    54
# Name: AGE, Length: 2216, dtype: int64
# ...
# 0       1190
# 1        577
# 2        251
# 3         11
# 4         91
#         ...
# 2235     689
# 2236      55
# 2237     309
# 2238    1383
# 2239    1078
# Name: TOTAL_SPENDING, Length: 2216, dtype: int64
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\2365355395.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NUMBER_CHILDREN"] = df["KIDHOME"] + df["TEENHOME"]
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\2365355395.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.columns = df.columns.str.upper()

# %%
df.columns
df1 = df[['INCOME', 'KIDHOME',
       'TEENHOME', 'DT_CUSTOMER', 'RECENCY', 'MNTWINES', 'MNTFRUITS',
       'MNTMEATPRODUCTS', 'MNTFISHPRODUCTS', 'MNTSWEETPRODUCTS',
       'MNTGOLDPRODS', 'NUMDEALSPURCHASES', 'NUMWEBPURCHASES',
       'NUMCATALOGPURCHASES', 'NUMSTOREPURCHASES', 'NUMWEBVISITSMONTH', 'COUNTRY',
       'NUMBER_CHILDREN', 'AGE', 'TOTAL_SPENDING']]
df1
# Out:
#        INCOME  KIDHOME  TEENHOME DT_CUSTOMER  RECENCY  MNTWINES  MNTFRUITS  \
# 0     84835.0        0         0  2014-06-16        0       189        104
# 1     57091.0        0         0  2014-06-15        0       464          5
# 2     67267.0        0         1  2014-05-13        0       134         11
# 3     32474.0        1         1  2014-05-11        0        10          0
# 4     21474.0        1         0  2014-04-08        0         6         16
# ...       ...      ...       ...         ...      ...       ...        ...
# 2235  66476.0        0         1  2013-03-07       99       372         18
# 2236  31056.0        1         0  2013-01-22       99         5         10
# 2237  46310.0        1         0  2012-12-03       99       185          2
# 2238  65819.0        0         0  2012-11-29       99       267         38
# 2239  94871.0        0         2  2012-09-01       99       169         24
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns



numerical_columns = [col for col in df1.select_dtypes(include=['int64','float64']).columns]


# Define the number of columns for the dashboard
num_cols = 6 # You can adjust this to your preference

# Calculate the number of rows needed
num_rows = (len(numerical_columns) + num_cols - 1) // num_cols

# Create a figure and axis objects for subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
fig.suptitle("Histograms of Numerical Columns", fontsize=16)

# Loop through numerical columns and create histograms in subplots
for i, column in enumerate(numerical_columns):
    row, col = i // num_cols, i % num_cols
    ax = axes[row, col]
    sns.histplot(df[column], bins=20, color='navy', kde=True, ax=ax)
    ax.set_title(f'{column}')
    ax.set_xlabel('Values')
    ax.set_ylabel('Frequency')

# Remove any empty subplots if the number of columns isn't a multiple of num_cols
for i in range(len(numerical_columns), num_rows * num_cols):
    fig.delaxes(axes[i // num_cols, i % num_cols])


plt.subplots_adjust(top=0.95)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only columns of type 'int64' (excluding the 'ID' column)
numerical_columns = [col for col in df1.select_dtypes(include=['int64','float64']).columns]

# Define the number of columns for the dashboard
num_cols = 3  # You can adjust this to your preference

# Calculate the number of rows needed
num_rows = (len(numerical_columns) + num_cols - 1) // num_cols

# Create a figure and axis objects for subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 5 * num_rows))
fig.suptitle("Box Plots of Numerical Columns (excluding 'ID')", fontsize=16)

# Loop through numerical columns and create box plots in subplots
for i, column in enumerate(numerical_columns):
    row, col = i // num_cols, i % num_cols
    ax = axes[row, col]
    sns.boxplot(data=df, x=column, ax=ax)
    ax.set_title(f'{column}')
    ax.set_xlabel(column)
    
# Remove any empty subplots if the number of columns isn't a multiple of num_cols
for i in range(len(numerical_columns), num_rows * num_cols):
    fig.delaxes(axes[i // num_cols, i % num_cols])

plt.tight_layout()
plt.subplots_adjust(top=0.91)
plt.show()

# %%
df.columns
df1 = df[['INCOME', 'KIDHOME',
       'TEENHOME', 'DT_CUSTOMER', 'RECENCY', 'MNTWINES', 'MNTFRUITS',
       'MNTMEATPRODUCTS', 'MNTFISHPRODUCTS', 'MNTSWEETPRODUCTS',
       'MNTGOLDPRODS', 'NUMDEALSPURCHASES', 'NUMWEBPURCHASES',
       'NUMCATALOGPURCHASES', 'NUMSTOREPURCHASES', 'NUMWEBVISITSMONTH', 'COUNTRY',
       'NUMBER_CHILDREN', 'AGE', 'TOTAL_SPENDING']]
df1
# Out:
#        INCOME  KIDHOME  TEENHOME DT_CUSTOMER  RECENCY  MNTWINES  MNTFRUITS  \
# 0     84835.0        0         0  2014-06-16        0       189        104
# 1     57091.0        0         0  2014-06-15        0       464          5
# 2     67267.0        0         1  2014-05-13        0       134         11
# 3     32474.0        1         1  2014-05-11        0        10          0
# 4     21474.0        1         0  2014-04-08        0         6         16
# ...       ...      ...       ...         ...      ...       ...        ...
# 2235  66476.0        0         1  2013-03-07       99       372         18
# 2236  31056.0        1         0  2013-01-22       99         5         10
# 2237  46310.0        1         0  2012-12-03       99       185          2
# 2238  65819.0        0         0  2012-11-29       99       267         38
# 2239  94871.0        0         2  2012-09-01       99       169         24
#
# ...

# %%
import pandas as pd

# Identify numerical columns
numerical_columns = [col for col in df1.select_dtypes(include=['int64','float64']).columns]
# Outlier Treatment
for column in numerical_columns:
    # Calculate the IQR for the column
    Q1 = df1[column].quantile(0.25)
    Q3 = df1[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Replace outliers with the median
    df1[column] = df1[column].apply(lambda x: df1[column].median() if x < lower_bound or x > upper_bound else x)

# Visualize the treated data (box plots)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(data=df1[numerical_columns], orient="h")
plt.title("Box Plots of Numerical Columns (Outlier Treated)")
plt.show()
# Out:
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\3860700767.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[column] = df1[column].apply(lambda x: df1[column].median() if x < lower_bound or x > upper_bound else x)
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\3860700767.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[column] = df1[column].apply(lambda x: df1[column].median() if x < lower_bound or x > upper_bound else x)
# ...

# %%
# Identify numerical columns
numerical_columns = [col for col in df1.select_dtypes(include='int64').columns]
# Outlier Treatment
for column in numerical_columns:
    # Calculate the IQR for the column
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Replace outliers with the median
    df[column] = df[column].apply(lambda x: df[column].median() if x < lower_bound or x > upper_bound else x)

# Visualize the treated data (box plots)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[numerical_columns], orient="h")
plt.title("Box Plots of Numerical Columns (Outlier Treated)")
plt.show()
# Out:
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\3300699164.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: df[column].median() if x < lower_bound or x > upper_bound else x)
# C:\Users\abubakr\AppData\Local\Temp\ipykernel_10176\3300699164.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].apply(lambda x: df[column].median() if x < lower_bound or x > upper_bound else x)
# ...

# %%
df.columns
df1 = df[['EDUCATION', 'MARITAL_STATUS', 'INCOME', 'KIDHOME',
       'TEENHOME', 'DT_CUSTOMER', 'RECENCY', 'MNTWINES', 'MNTFRUITS',
       'MNTMEATPRODUCTS', 'MNTFISHPRODUCTS', 'MNTSWEETPRODUCTS',
       'MNTGOLDPRODS', 'NUMDEALSPURCHASES', 'NUMWEBPURCHASES',
       'NUMCATALOGPURCHASES','AGE', 'NUMSTOREPURCHASES', 'NUMWEBVISITSMONTH', 'COUNTRY',
       'NUMBER_CHILDREN','TOTAL_SPENDING']]
df1
# Out:
#        EDUCATION MARITAL_STATUS   INCOME  KIDHOME  TEENHOME DT_CUSTOMER  \
# 0     graduation       divorced  84835.0        0         0  2014-06-16
# 1     graduation         single  57091.0        0         0  2014-06-15
# 2     graduation        married  67267.0        0         1  2014-05-13
# 3     graduation       together  32474.0        1         1  2014-05-11
# 4     graduation         single  21474.0        1         0  2014-04-08
# ...          ...            ...      ...      ...       ...         ...
# 2235         phd       divorced  66476.0        0         1  2013-03-07
# 2236    2n cycle        married  31056.0        1         0  2013-01-22
# 2237  graduation       divorced  46310.0        1         0  2012-12-03
# 2238  graduation        married  65819.0        0         0  2012-11-29
# 2239         phd        married  94871.0        0         2  2012-09-01
#
#       RECENCY  MNTWINES  MNTFRUITS  MNTMEATPRODUCTS  ...  MNTGOLDPRODS  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numerical columns (int64 and float64) and exclude 'ID'
numerical_columns = [col for col in df1.select_dtypes(include=['int64', 'float64']).columns]

# Compute the correlation matrix for the selected numerical columns
corr_matrix = df[numerical_columns].corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5, annot_kws={"size": 10})
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Stage 3

# %% [markdown]
# ##### Older people are not as tech-savvy and probably prefer shopping in-store.

# %%
import pandas as pd
from scipy import stats

# Load your CSV data into a DataFrame (assuming your CSV file is named 'data.csv')


# Split the data into two groups: people aged 50 or older and people younger than 50
older_age = df[df['AGE'] >= 50]
web_shopping = older_age['NUMWEBPURCHASES']
store_shopping = older_age['NUMSTOREPURCHASES']
# Perform the t-test
_, p_value = stats.ttest_ind(store_shopping,web_shopping,alternative="greater")
# Set the significance level (alpha)
alpha = 0.05

# Print the results
#print("t-statistic:", t_statistic)
print("p-value:", p_value)

# Compare the p-value to alpha and make a conclusion
if p_value <= alpha:
    print("Reject the null hypothesis: lder people are not as tech-savvy and probably prefer shopping in-store.")
else:
    print("Fail to reject the null hypothesis: older peole are happy with shopping in store.")
# Out:
# p-value: 1.9177280035865163e-46
# Reject the null hypothesis: lder people are not as tech-savvy and probably prefer shopping in-store.

# %% [markdown]
# ##### Customers with kids probably have less time to visit a store and would prefer to shop online.

# %%
#NUMBER_CHILDREN 

import pandas as pd
from scipy import stats

# Load your CSV data into a DataFrame (assuming your CSV file is named 'data.csv')


# Split the data into two groups: people aged 50 or older and people younger than 50
kids = df[df['NUMBER_CHILDREN'] > 0]
web_shopping = kids['NUMWEBPURCHASES']
store_shopping = kids['NUMSTOREPURCHASES']
# Perform the t-test
_, p_value = stats.ttest_ind(store_shopping,web_shopping,alternative="greater")
# Set the significance level (alpha)
alpha = 0.05

# Print the results
#print("t-statistic:", t_statistic)
print("p-value:", p_value)

# Compare the p-value to alpha and make a conclusion
if p_value <= alpha:
    print("Reject the null hypothesis: People with children are more likely to do shopping through web stores.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in shopping behavior between people with and without children.")
# Out:
# p-value: 5.6470528373001485e-33
# Reject the null hypothesis: People with children are more likely to do shopping through web stores.

# %% [markdown]
# ##### Other distribution channels may cannibalize sales at the store.

# %%
import pandas as pd
from scipy import stats

# Load your data into the 'df' DataFrame

# Define your groups
web_shoppers = df[df['NUMWEBPURCHASES'] > 0]
catalog_shoppers = df[df['NUMCATALOGPURCHASES'] > 0]
in_store_shoppers = df[df['NUMSTOREPURCHASES'] > 0]

# Perform t-tests
_, p_value_web = stats.ttest_ind(in_store_shoppers['NUMSTOREPURCHASES'], web_shoppers['NUMSTOREPURCHASES'])
_, p_value_catalog = stats.ttest_ind(in_store_shoppers['NUMSTOREPURCHASES'], catalog_shoppers['NUMSTOREPURCHASES'])

# Set the significance level (alpha)
alpha = 0.05

# Print the results and make conclusions
print("Web vs. In-Store:")
print("p-value:", p_value_web)
if p_value_web <= alpha:
    print("Reject the null hypothesis: Web purchases may cannibalize in-store sales.")
else:
    print("Fail to reject the null hypothesis: No significant difference observed.")

print("\nCatalog vs. In-Store:")
print("p-value:", p_value_catalog)
if p_value_catalog <= alpha:
    print("Reject the null hypothesis: Catalog purchases may cannibalize in-store sales.")
else:
    print("Fail to reject the null hypothesis: No significant difference observed.")
# Out:
# Web vs. In-Store:
# p-value: 0.6455449005322863
# Fail to reject the null hypothesis: No significant difference observed.
#
# Catalog vs. In-Store:
# p-value: 7.044387037037154e-20
# Reject the null hypothesis: Catalog purchases may cannibalize in-store sales.

# %% [markdown]
# #### Does the US fare significantly better than the rest of the world in terms of total purchases?

# %%
import pandas as pd
from scipy import stats

# Load your data into the 'df' DataFrame

# Separate the data into U.S. customers and rest of the world customers
us_customers = df[df['COUNTRY'] == 'us']
rest_of_world_customers = df[df['COUNTRY'] != 'us']

# Perform a t-test to compare total purchases between U.S. and rest of the world customers
_, p_value = stats.ttest_ind(us_customers['TOTAL_SPENDING'], rest_of_world_customers['TOTAL_SPENDING'])

# Set the significance level (alpha)
alpha = 0.05

# Print the results and make a conclusion
print("p-value:", p_value)
if p_value <= alpha:
    print("Reject the null hypothesis: The United States fares significantly better in terms of total purchases.")
else:
    print("Fail to reject the null hypothesis: No significant difference observed.")
# Out:
# p-value: 0.6705488587217316
# Fail to reject the null hypothesis: No significant difference observed.

# %% [markdown]
# ## Data visualisation

# %% [markdown]
# ##### Which products are performing the best, and which are performing the least in terms of revenue?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt




product_categories = ['Wines', 'Fruits', 'Meat', 'Fish', 'Sweets', 'Gold']

product_revenue = pd.DataFrame({'Category': product_categories})

product_revenue['Total Revenue'] = df[['MNTWINES', 'MNTFRUITS', 'MNTMEATPRODUCTS', 'MNTFISHPRODUCTS', 'MNTSWEETPRODUCTS', 'MNTGOLDPRODS']].sum().values

product_revenue = product_revenue.sort_values(by='Total Revenue', ascending=False)

# Create a bar plot using Seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='Category', y='Total Revenue', data=product_revenue, palette='viridis')
plt.title('Product Revenue')
plt.xlabel('Product Category')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ##### Is there any pattern between the age of customers and the last campaign acceptance rate?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(5,2))
sns.scatterplot(x='AGE', y='ACCEPTEDCMP5',data = df)
plt.title('Age vs. Last Campaign Acceptance Rate')
plt.xlabel('Age')
plt.ylabel('Last Campaign Acceptance Rate')
plt.show()

# %% [markdown]
# ##### Which Country has the greatest number of customers who accepted the last campaign?

# %%
accepted_campaign_customers = df[df['ACCEPTEDCMP5'] == 1]

# Create a bar plot to show the number of acceptances by country
plt.figure(figsize=(12, 6))
sns.countplot(x='COUNTRY', data=accepted_campaign_customers)
plt.title('Number of Campaign Acceptances by Country')
plt.xlabel('Country')
plt.ylabel('Number of Acceptances')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(5, 2))
sns.scatterplot(x='KIDHOME', y='TOTAL_SPENDING', data=df)
plt.title('Age vs. Last Campaign Acceptance Rate')
plt.xlabel('Number of children (At Home)')
plt.ylabel('Total spend')
plt.show()

# %%
df.groupby('EDUCATION').sum(numeric_only=True).sort_values(by='COMPLAIN',ascending = False)['COMPLAIN']
# Out:
# EDUCATION
# graduation    14
# 2n cycle       4
# master         2
# phd            1
# basic          0
# Name: COMPLAIN, dtype: int64

# %%
df['COMPLAIN'].sum()
# Out:
# 21

# %%
import matplotlib.pyplot as plt

# Education levels and corresponding complaint counts
education_levels = ["graduation", "2n cycle", "master", "phd", "basic"]
complaint_counts = [14, 4, 2, 1, 0]

# Set a custom color palette
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightblue', 'lightgray']

# Create a bar chart with better styling
plt.figure(figsize=(8, 6))
plt.bar(education_levels, complaint_counts, color=colors)

# Add labels to the bars
for i, count in enumerate(complaint_counts):
    plt.text(i, count, str(count), ha='center', va='bottom', fontsize=12)

# Set labels and title
plt.xlabel("Education Level", fontsize=14)
plt.ylabel("Number of Complaints", fontsize=14)
plt.title("Complaints by Education Level", fontsize=16)

# Customize grid lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=12)

# Set axis label fonts
plt.tick_params(axis='both', which='major', labelsize=12)

# Show the plot
plt.show()

# %%
### insight
### The data reveals that individuals with different education levels 
### have varying levels of engagement and satisfaction with the services or products,
### as reflected in their complaints. 
### Understanding the specific concerns and needs of each education group is essential for tailoring support and services effectively.
